# %% [markdown]
# <a href="https://colab.research.google.com/github/anderson-ferreira-83/Article_publish_comp_lattices_thin_plate_2023_anderson_83/blob/main/sec4_2_res1_stat_descritive_lattices/results_tr_lattices_3_regions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Data for transmittances
data_10_50 = {
    "Frequency [Hz]": [10.0000, 20.0000, 30.0000, 40.0000, 50.0000],
    "Square Lattice [dB]": [-91.9190, -128.5100, -150.0500, -173.0900, -162.3300],
    "Rectangular Lattice [dB]": [-77.6910, -105.9800, -122.4600, -129.9300, -129.5100],
    "Triangular Lattice [dB]": [-97.6010, -133.4100, -157.8600, -174.1900, -158.9700],
    "Honeycomb Lattice 1 [dB]": [-185.0900, -217.3400, -220.3300, -201.5500, -155.4300],
    "Honeycomb Lattice 2 [dB]": [-3.8906, -12.6170, -11.6120, -20.0590, -64.2810],
    "Kagome Lattice 1 [dB]": [-260.5100, -292.6500, -211.2600, -183.0800, -100.2800],
    "Kagome Lattice 2 [dB]": [-3.6778, -6.1471, -14.9460, -47.6360, -96.8090],
}

# %%
data_60_100 = {
    "Frequency [Hz]": [60.0000, 70.0000, 80.0000, 90.0000, 100.0000],
    "Square Lattice [dB]": [-141.1600, -115.7500, -105.4000, -88.2240, -72.0070],
    "Rectangular Lattice [dB]": [-119.8200, -104.0400, -107.5200, -121.2600, -84.5190],
    "Triangular Lattice [dB]": [-193.4400, -191.3600, -154.4600, -134.0500, -116.5700],
    "Honeycomb Lattice 1 [dB]": [-83.4050, -54.4570, -15.8660, -7.3681, -28.3560],
    "Honeycomb Lattice 2 [dB]": [-119.6000, -148.1600, -153.1600, -163.8200, -165.8300],
    "Kagome Lattice 1 [dB]": [-100.7000, -98.5310, -111.4800, -79.8450, -48.7800],
    "Kagome Lattice 2 [dB]": [-96.1070, -157.2400, -198.2700, -143.8500, -159.5600],
}

# %%
data_110_150 = {
    "Frequency [Hz]": [110.0000, 120.0000, 130.0000, 140.0000, 150.0000],
    "Square Lattice [dB]": [-18.9370, -20.5480, -21.2610, -19.9180, -17.8130],
    "Rectangular Lattice [dB]": [-65.5820, -62.1420, -89.7060, -84.1660, -79.8170],
    "Triangular Lattice [dB]": [-99.7990, -90.7010, -98.5920, -88.6710, -69.1090],
    "Honeycomb Lattice 1 [dB]": [-10.5920, -0.7619, -3.7856, -5.5461, -8.1006],
    "Honeycomb Lattice 2 [dB]": [-151.0000, -141.9800, -112.7100, -88.6710, -48.7470],
    "Kagome Lattice 1 [dB]": [-22.9070, -19.1790, -4.8339, -8.2441, -19.1190],
    "Kagome Lattice 2 [dB]": [-145.4500, -114.7300, -71.6800, -60.0870, -61.8320],
}

# %%
# Criação de DataFrames
df_10_50 = pd.DataFrame(data_10_50)
df_60_100 = pd.DataFrame(data_60_100)
df_110_150 = pd.DataFrame(data_110_150)

# %%
df_10_50
# Out:
#    Frequency [Hz]  Square Lattice [dB]  Rectangular Lattice [dB]  \
# 0            10.0              -91.919                   -77.691
# 1            20.0             -128.510                  -105.980
# 2            30.0             -150.050                  -122.460
# 3            40.0             -173.090                  -129.930
# 4            50.0             -162.330                  -129.510
#
#    Triangular Lattice [dB]  Honeycomb Lattice 1 [dB]  \
# 0                  -97.601                   -185.09
# 1                 -133.410                   -217.34
# 2                 -157.860                   -220.33
# 3                 -174.190                   -201.55
# 4                 -158.970                   -155.43
#
#    Honeycomb Lattice 2 [dB]  Kagome Lattice 1 [dB]  Kagome Lattice 2 [dB]
# 0                   -3.8906                -260.51                -3.6778
# 1                  -12.6170                -292.65                -6.1471
# ...

# %%
df_60_100
# Out:
#    Frequency [Hz]  Square Lattice [dB]  Rectangular Lattice [dB]  \
# 0            60.0             -141.160                  -119.820
# 1            70.0             -115.750                  -104.040
# 2            80.0             -105.400                  -107.520
# 3            90.0              -88.224                  -121.260
# 4           100.0              -72.007                   -84.519
#
#    Triangular Lattice [dB]  Honeycomb Lattice 1 [dB]  \
# 0                  -193.44                  -83.4050
# 1                  -191.36                  -54.4570
# 2                  -154.46                  -15.8660
# 3                  -134.05                   -7.3681
# 4                  -116.57                  -28.3560
#
#    Honeycomb Lattice 2 [dB]  Kagome Lattice 1 [dB]  Kagome Lattice 2 [dB]
# 0                   -119.60               -100.700                -96.107
# 1                   -148.16                -98.531               -157.240
# ...

# %%
df_110_150
# Out:
#    Frequency [Hz]  Square Lattice [dB]  Rectangular Lattice [dB]  \
# 0           110.0              -18.937                   -65.582
# 1           120.0              -20.548                   -62.142
# 2           130.0              -21.261                   -89.706
# 3           140.0              -19.918                   -84.166
# 4           150.0              -17.813                   -79.817
#
#    Triangular Lattice [dB]  Honeycomb Lattice 1 [dB]  \
# 0                  -99.799                  -10.5920
# 1                  -90.701                   -0.7619
# 2                  -98.592                   -3.7856
# 3                  -88.671                   -5.5461
# 4                  -69.109                   -8.1006
#
#    Honeycomb Lattice 2 [dB]  Kagome Lattice 1 [dB]  Kagome Lattice 2 [dB]
# 0                  -151.000               -22.9070               -145.450
# 1                  -141.980               -19.1790               -114.730
# ...

# %%
# Exportando para CSV
df_10_50.to_csv('frequencies_10_50.csv', index=False)
df_60_100.to_csv('frequencies_60_100.csv', index=False)
df_110_150.to_csv('frequencies_110_150.csv', index=False)

# %%
# Concatenando os DataFrames
df_concatenated = pd.concat([df_10_50, df_60_100, df_110_150], axis=0)

# %%
df_concatenated
# Out:
#    Frequency [Hz]  Square Lattice [dB]  Rectangular Lattice [dB]  \
# 0            10.0              -91.919                   -77.691
# 1            20.0             -128.510                  -105.980
# 2            30.0             -150.050                  -122.460
# 3            40.0             -173.090                  -129.930
# 4            50.0             -162.330                  -129.510
# 0            60.0             -141.160                  -119.820
# 1            70.0             -115.750                  -104.040
# 2            80.0             -105.400                  -107.520
# 3            90.0              -88.224                  -121.260
# 4           100.0              -72.007                   -84.519
# 0           110.0              -18.937                   -65.582
# 1           120.0              -20.548                   -62.142
# 2           130.0              -21.261                   -89.706
# ...

# %%
df_concatenated.describe()
# Out:
#        Frequency [Hz]  Square Lattice [dB]  Rectangular Lattice [dB]  \
# count        15.00000            15.000000                 15.000000
# mean         80.00000           -88.461133                -98.942867
# std          44.72136            57.170335                 22.877002
# min          10.00000          -173.090000               -129.930000
# 25%          45.00000          -134.835000               -120.540000
# 50%          80.00000           -91.919000               -104.040000
# 75%         115.00000           -20.904500                -81.991500
# max         150.00000           -17.813000                -62.142000
#
#        Triangular Lattice [dB]  Honeycomb Lattice 1 [dB]  \
# count                15.000000                 15.000000
# mean               -130.585533                -79.865220
# std                  39.702369                 88.801504
# min                -193.440000               -220.330000
# ...

# %%
# Exportando o DataFrame para um arquivo CSV
df_concatenated.to_csv('data_lattices_transmittance.csv', index=False)

print("data exported'")
# Out:
# Dados exportados para 'dados_concatenados.csv'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Seleciona todas as colunas, exceto 'Frequency [Hz]'
data_for_boxplot = df_concatenated.drop(columns=['Frequency [Hz]'])

sns.boxplot(data=data_for_boxplot)
plt.xticks(rotation=45, ha='right')  # Rotaciona os labels do eixo x para melhor visualização
plt.show()
